# %%
#importa framework Keras 
from keras.layers import Convolution2D, MaxPooling2D, Activation
from keras.models import Sequential
#importa numpy para os cálculos
import numpy as np
#importa matplotlib para "plotar" as imagens
import matplotlib.pyplot as plt
#importa cv2 para fazer o "read" da imagem
import cv2

# %%
#Através do módulo cv2 faz o "read" da imagem
cat = cv2.imread('E:\cat.png')
#"Plota" a imamgem na tela
plt.imshow(cat)
plt.show()

# %%
#"Shape" da imagem
cat.shape
# Out:
# (320, 400, 3)

# %% [markdown]
# Camada de convolução com filtros 3X3 utilizando o modelo sequencial do Keras

# %%
#Modelo sequêncial Keras
model = Sequential()
# Camada de convolução com entrada cat.shape e filtros 3X3
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
#Aumenta 1 dimensão
cat_batch = np.expand_dims(cat,axis=0)
#conv_cat recebe a saída das predições para o sample catch_batch
conv_cat = model.predict(cat_batch)
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   after removing the cwd from sys.path.

# %%
#função para plotar exibit o "shape" e "plotar" na tela a imagem da convolução
def visualize_cat(model, cat):
    cat_batch = np.expand_dims(cat,axis=0)
    conv_cat = model.predict(cat_batch)
    conv_cat = np.squeeze(conv_cat, axis=0)
    print(conv_cat.shape)
    plt.imshow(conv_cat)
    plt.show()

# %%
#"Plota" imagem
visualize_cat(model, cat)
# Out:
# (318, 398, 3)

# %% [markdown]
# Camada de convolução com filtros 10X10 utilizando o modelo sequencial do Keras

# %%
model = Sequential()
model.add(Convolution2D(3, 10,10,input_shape=cat.shape))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (10, 10), input_shape=(320, 400,...)`

# %%
#"Plota" imagem
visualize_cat(model, cat)
# Out:
# (311, 391, 3)

# %%
#Função para "Plotar" imagem após Reshape
def imprime_gatinho_fofo(model, cat):
    cat_batch = np.expand_dims(cat,axis=0)
    conv_cat2 = model.predict(cat_batch)
    conv_cat2 = np.squeeze(conv_cat2, axis=0)
    print(conv_cat2.shape)
    conv_cat2 = conv_cat2.reshape(conv_cat2.shape[:2])
    print(conv_cat2.shape)
    plt.imshow(conv_cat2)
    plt.show()

# %% [markdown]
# Camada de convolução filtros 3X3N

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`

# %%
#"Plotar" imagem 
imprime_gatinho_fofo(model, cat)
# Out:
# (318, 398, 1)
# (318, 398)

# %% [markdown]
# Convolução com filtro '5X15

# %%
model = Sequential()
model.add(Convolution2D(1,15,15,input_shape=cat.shape))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (15, 15), input_shape=(320, 400,...)`

# %%
#"Plotar" imagem 
imprime_gatinho_fofo(model, cat)
# Out:
# (306, 386, 1)
# (306, 386)

# %% [markdown]
# Convolução com filtros 3X3 + camada ReLU

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`

# %%
#"Plotar" imagem 
imprime_gatinho_fofo(model, cat)
# Out:
# (318, 398, 1)
# (318, 398)

# %% [markdown]
# Convolução com filtros 3X3 + camada ReLU

# %%
model = Sequential()
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`

# %%
visualize_cat(model, cat)
# Out:
# (318, 398, 3)

# %% [markdown]
# Convolução com filtros 3X3 + camada Pooling 5X5

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(MaxPooling2D(pool_size=(5,5)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`

# %%
#"Plotar" imagem 
imprime_gatinho_fofo(model, cat)
# Out:
# (63, 79, 1)
# (63, 79)

# %% [markdown]
# Convolução com filtros 3X3 + camada Pooling 5X5

# %%
model = Sequential()
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
model.add(MaxPooling2D(pool_size=(5,5)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`

# %%
visualize_cat(model, cat)
# Out:
# (63, 79, 3)

# %% [markdown]
# Convolução com filtros 3x3 + ReLU + Pooling

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`

# %%
imprime_gatinho_fofo(model, cat)
# Out:
# (63, 79, 1)
# (63, 79)

# %% [markdown]
# 2 Camadas de convolução + ReLU  + Pooling

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """

# %%
imprime_gatinho_fofo(model, cat)
# Out:
# (34, 43, 1)
# (34, 43)

# %% [markdown]
# 2 Camadas de convolução + ReLU  + Pooling

# %%
model = Sequential()
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """

# %%
imprime_gatinho_fofo(model, cat)
# Out:
# (52, 65, 1)
# (52, 65)

# %% [markdown]
# 2 Camadas de convolução + ReLU  + Pooling

# %%
model = Sequential()
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(3,3,3,input_shape=cat.shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#
# c:\users\leonardo\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   """

# %%
visualize_cat(model, cat)
# Out:
# (52, 65, 3)
